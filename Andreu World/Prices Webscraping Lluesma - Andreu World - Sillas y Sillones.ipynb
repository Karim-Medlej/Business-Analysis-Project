# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd

# %% [markdown]
# # Web Scraping
# ### Page 1 / 2 / 3 / 4 / 5 / 6

# %%
#Page1#
url_lluesma = "https://www.muebleslluesma.com/2212-sillas-andreu-world  "
page_lluesma = urlopen(url_lluesma)

soup_lluesma = bs(page_lluesma, 'html.parser')
print(soup_lluesma.prettify().splitlines()[0:30])

names_lluesma = soup_lluesma.find_all('h3', class_='h3 product-title')

for name in names_lluesma[0:20]:
    print(name.prettify())
    
description_lluesma = soup_lluesma.find_all('div', class_='product-description-short')

for description in description_lluesma[0:20]:
    print(description.prettify())

prices_lluesma = soup_lluesma.find_all('span', class_='price')

for prices in prices_lluesma[0:20]:
    print(prices.prettify())


#Page2#
url_lluesma_page2 = "https://www.muebleslluesma.com/2212-sillas-andreu-world?page=2"
page_lluesma_page2 = urlopen(url_lluesma_page2)

soup_lluesma_page2 = bs(page_lluesma_page2, 'html.parser')
print(soup_lluesma_page2.prettify().splitlines()[0:30])

names_lluesma_page2 = soup_lluesma_page2.find_all('h3', class_='h3 product-title')

for name_page2 in names_lluesma_page2[0:20]:
    print(name_page2.prettify())
    
description_lluesma_page2 = soup_lluesma_page2.find_all('div', class_='product-description-short')

for description_page2 in description_lluesma_page2[0:20]:
    print(description_page2.prettify())
    
prices_lluesma_page2 = soup_lluesma_page2.find_all('span', class_='price')

for prices_page2 in prices_lluesma_page2[0:20]:
    print(prices_page2.prettify())


#Page3#
url_lluesma_page3 = "https://www.muebleslluesma.com/2212-sillas-andreu-world?page=3"
page_lluesma_page3 = urlopen(url_lluesma_page3)

soup_lluesma_page3 = bs(page_lluesma_page3, 'html.parser')
print(soup_lluesma_page3.prettify().splitlines()[0:30])

names_lluesma_page3 = soup_lluesma_page3.find_all('h3', class_='h3 product-title')

for name_page3 in names_lluesma_page3[0:20]:
    print(name_page3.prettify())
    
description_lluesma_page3 = soup_lluesma_page3.find_all('div', class_='product-description-short')

for description_page3 in description_lluesma_page3[0:20]:
    print(description_page3.prettify())
    
prices_lluesma_page3 = soup_lluesma_page3.find_all('span', class_='price')

for prices_page3 in prices_lluesma_page3[0:20]:
    print(prices_page3.prettify())


#Page4#
url_lluesma_page4 = "https://www.muebleslluesma.com/2212-sillas-andreu-world?page=4"
page_lluesma_page4 = urlopen(url_lluesma_page4)

soup_lluesma_page4 = bs(page_lluesma_page4, 'html.parser')
print(soup_lluesma_page4.prettify().splitlines()[0:30])

names_lluesma_page4 = soup_lluesma_page4.find_all('h3', class_='h3 product-title')

for name_page4 in names_lluesma_page4[0:20]:
    print(name_page4.prettify())
    
description_lluesma_page4 = soup_lluesma_page4.find_all('div', class_='product-description-short')

for description_page4 in description_lluesma_page4[0:20]:
    print(description_page4.prettify())
    
prices_lluesma_page4 = soup_lluesma_page4.find_all('span', class_='price')

for prices_page4 in prices_lluesma_page4[0:20]:
    print(prices_page4.prettify())


#Page5#
url_lluesma_page5 = "https://www.muebleslluesma.com/2212-sillas-andreu-world?page=5"
page_lluesma_page5 = urlopen(url_lluesma_page5)

soup_lluesma_page5 = bs(page_lluesma_page5, 'html.parser')
print(soup_lluesma_page5.prettify().splitlines()[0:30])

names_lluesma_page5 = soup_lluesma_page5.find_all('h3', class_='h3 product-title')

for name_page5 in names_lluesma_page5[0:20]:
    print(name_page5.prettify())
    
description_lluesma_page5 = soup_lluesma_page5.find_all('div', class_='product-description-short')

for description_page5 in description_lluesma_page5[0:20]:
    print(description_page5.prettify())
    
prices_lluesma_page5 = soup_lluesma_page5.find_all('span', class_='price')

for prices_page5 in prices_lluesma_page5[0:20]:
    print(prices_page5.prettify())


#Page6#
url_lluesma_page6 = "https://www.muebleslluesma.com/2212-sillas-andreu-world?page=6"
page_lluesma_page6 = urlopen(url_lluesma_page6)

soup_lluesma_page6 = bs(page_lluesma_page6, 'html.parser')
print(soup_lluesma_page6.prettify().splitlines()[0:30])

names_lluesma_page6 = soup_lluesma_page6.find_all('h3', class_='h3 product-title')

for name_page6 in names_lluesma_page6[0:20]:
    print(name_page6.prettify())
    
description_lluesma_page6 = soup_lluesma_page6.find_all('div', class_='product-description-short')

for description_page6 in description_lluesma_page6[0:20]:
    print(description_page6.prettify())
    
prices_lluesma_page6 = soup_lluesma_page6.find_all('span', class_='price')

for prices_page6 in prices_lluesma_page6[0:20]:
    print(prices_page6.prettify())
# Out:
# ['<!DOCTYPE html>', '<html class="default" lang="es-ES">', ' <head>', '  <meta charset="utf-8"/>', '  <meta content="ie=edge" http-equiv="x-ua-compatible"/>', '  <title>', '   Sillas de Andreu World. Muebles Lluesma', '  </title>', '  <meta content="Las sillas diseñadas por Andreu World son de arte contemporáneo. Ideales para el hogar, oficina y exterior. Las sillas Andreu World son versátiles, completamente tapizada con estructura de madera maciza y metálica. Las sillas son giratorias, ergonómicas." name="description"/>', '  <meta content="" name="keywords"/>', '  <link href="https://www.muebleslluesma.com/2212-sillas-andreu-world" rel="canonical"/>', '  <script type="application/ld+json">', '   {', '    "@context": "https://schema.org",', '    "@type": "Organization",', '    "name" : "Muebles Lluesma",', '    "url" : "https://www.muebleslluesma.com/",', '        "logo": {', '      "@type": "ImageObject",', '        "url":"https://www.muebleslluesma.com/img/logo-1647335525.jpg"', ' 
# ...

# %%
#Page1#
titles = []
descriptions = []
prices = []

for i in range(len(names_lluesma)):
    title = names_lluesma[i].text if names_lluesma[i] else None
    description = description_lluesma[i].text.strip() if description_lluesma[i] else None
    price = prices_lluesma[i].text.replace('\n', '') if prices_lluesma[i] else None
    
    titles.append(title)
    descriptions.append(description)
    prices.append(price)

df_lluesma = pd.DataFrame({'Title': titles, 'Description': descriptions, 'Price': prices})

#Page2#
titles = []
descriptions = []
prices = []

for i in range(len(names_lluesma_page2)):
    title = names_lluesma_page2[i].text if names_lluesma_page2[i] else None
    description = description_lluesma_page2[i].text.strip() if description_lluesma_page2[i] else None
    price = prices_lluesma_page2[i].text.replace('\n', '') if prices_lluesma_page2[i] else None
    
    titles.append(title)
    descriptions.append(description)
    prices.append(price)

df_lluesma_page2 = pd.DataFrame({'Title': titles, 'Description': descriptions, 'Price': prices})

#Page3#
titles = []
descriptions = []
prices = []

for i in range(len(names_lluesma_page3)):
    title = names_lluesma_page3[i].text if names_lluesma_page3[i] else None
    description = description_lluesma_page3[i].text.strip() if description_lluesma_page3[i] else None
    price = prices_lluesma_page3[i].text.replace('\n', '') if prices_lluesma_page3[i] else None
    
    titles.append(title)
    descriptions.append(description)
    prices.append(price)

df_lluesma_page3 = pd.DataFrame({'Title': titles, 'Description': descriptions, 'Price': prices})

#Page4#
titles = []
descriptions = []
prices = []

for i in range(len(names_lluesma_page4)):
    title = names_lluesma_page4[i].text if names_lluesma_page4[i] else None
    description = description_lluesma_page4[i].text.strip() if description_lluesma_page4[i] else None
    price = prices_lluesma_page4[i].text.replace('\n', '') if prices_lluesma_page4[i] else None
    
    titles.append(title)
    descriptions.append(description)
    prices.append(price)

df_lluesma_page4 = pd.DataFrame({'Title': titles, 'Description': descriptions, 'Price': prices})

#Page5#
titles = []
descriptions = []
prices = []

for i in range(len(names_lluesma_page5)):
    title = names_lluesma_page5[i].text if names_lluesma_page5[i] else None
    description = description_lluesma_page5[i].text.strip() if description_lluesma_page5[i] else None
    price = prices_lluesma_page5[i].text.replace('\n', '') if prices_lluesma_page5[i] else None
    
    titles.append(title)
    descriptions.append(description)
    prices.append(price)

df_lluesma_page5 = pd.DataFrame({'Title': titles, 'Description': descriptions, 'Price': prices})

#Page6#
titles = []
descriptions = []
prices = []

for i in range(len(names_lluesma_page6)):
    title = names_lluesma_page6[i].text if names_lluesma_page6[i] else None
    description = description_lluesma_page6[i].text.strip() if description_lluesma_page6[i] else None
    price = prices_lluesma_page6[i].text.replace('\n', '') if prices_lluesma_page6[i] else None
    
    titles.append(title)
    descriptions.append(description)
    prices.append(price)

df_lluesma_page6 = pd.DataFrame({'Title': titles, 'Description': descriptions, 'Price': prices})

# %% [markdown]
# # Data Frame Manipulation
# ### Merging all pages

# %%
pd.set_option('display.max_rows', None)

df_combined_andreu_sillas_sillones = pd.concat([df_lluesma, df_lluesma_page2, df_lluesma_page3, df_lluesma_page4, df_lluesma_page5, df_lluesma_page6], ignore_index=True)
df_combined_andreu_sillas_sillones.head(200)
# Out:
#                                                  Title  \
# 0            Silla Lineal SI-0760/SO-0761 Andreu World
# 1    Silla Lineal comfort SI-0594/SO-0595 Andreu World
# 2    Silla Lineal comfort SI-0567/SO-0568 Andreu World
# 3    Silla Lineal comfort SI-0606/SO-0607 Andreu World
# 4                       Silla Nub SI-1449 Andreu World
# 5                      Silla Sail SI-1245 Andreu World
# 6                      Silla Lake SI-0653 Andreu World
# 7            Silla Lineal SI-0582/SO-0583 Andreu World
# 8                     Silla Happy SI-0377 Andreu World
# 9             Silla New Anna SI-1370/1372 Andreu World
# 10                   Silla Carlotta Small Andreu World
# 11                     Silla Carlotta Big Andreu World
# 12                             Silla Solo Andreu World
# 13                   Sillón Solo tapizado Andreu World
# 14                     Sillón Solo madera Andreu World
# 15                           Silla Serena Andreu World
# ...

# %% [markdown]
# ### Extraction of infromation from 'Title' column

# %%
df_combined_andreu_sillas_sillones.dtypes
# Out:
# Title          object
# Description    object
# Price          object
# dtype: object

# %%
df_combined_andreu_sillas_sillones[['Category','Product']] = df_combined_andreu_sillas_sillones['Title'].str.split(' ', n=1, expand=True)
df_combined_andreu_sillas_sillones
# Out:
#                                                  Title  \
# 0            Silla Lineal SI-0760/SO-0761 Andreu World
# 1    Silla Lineal comfort SI-0594/SO-0595 Andreu World
# 2    Silla Lineal comfort SI-0567/SO-0568 Andreu World
# 3    Silla Lineal comfort SI-0606/SO-0607 Andreu World
# 4                       Silla Nub SI-1449 Andreu World
# 5                      Silla Sail SI-1245 Andreu World
# 6                      Silla Lake SI-0653 Andreu World
# 7            Silla Lineal SI-0582/SO-0583 Andreu World
# 8                     Silla Happy SI-0377 Andreu World
# 9             Silla New Anna SI-1370/1372 Andreu World
# 10                   Silla Carlotta Small Andreu World
# 11                     Silla Carlotta Big Andreu World
# 12                             Silla Solo Andreu World
# 13                   Sillón Solo tapizado Andreu World
# 14                     Sillón Solo madera Andreu World
# 15                           Silla Serena Andreu World
# ...

# %%
df_combined_andreu_sillas_sillones['Company'] = 'Andreu World'
df_combined_andreu_sillas_sillones
# Out:
#                                                  Title  \
# 0            Silla Lineal SI-0760/SO-0761 Andreu World
# 1    Silla Lineal comfort SI-0594/SO-0595 Andreu World
# 2    Silla Lineal comfort SI-0567/SO-0568 Andreu World
# 3    Silla Lineal comfort SI-0606/SO-0607 Andreu World
# 4                       Silla Nub SI-1449 Andreu World
# 5                      Silla Sail SI-1245 Andreu World
# 6                      Silla Lake SI-0653 Andreu World
# 7            Silla Lineal SI-0582/SO-0583 Andreu World
# 8                     Silla Happy SI-0377 Andreu World
# 9             Silla New Anna SI-1370/1372 Andreu World
# 10                   Silla Carlotta Small Andreu World
# 11                     Silla Carlotta Big Andreu World
# 12                             Silla Solo Andreu World
# 13                   Sillón Solo tapizado Andreu World
# 14                     Sillón Solo madera Andreu World
# 15                           Silla Serena Andreu World
# ...

# %% [markdown]
# ### Deletion of repeated and unnecessary info

# %%
df_combined_andreu_sillas_sillones['Product'] = df_combined_andreu_sillas_sillones['Product'].str.replace('Andreu World','')
df_combined_andreu_sillas_sillones
# Out:
#                                                  Title  \
# 0            Silla Lineal SI-0760/SO-0761 Andreu World
# 1    Silla Lineal comfort SI-0594/SO-0595 Andreu World
# 2    Silla Lineal comfort SI-0567/SO-0568 Andreu World
# 3    Silla Lineal comfort SI-0606/SO-0607 Andreu World
# 4                       Silla Nub SI-1449 Andreu World
# 5                      Silla Sail SI-1245 Andreu World
# 6                      Silla Lake SI-0653 Andreu World
# 7            Silla Lineal SI-0582/SO-0583 Andreu World
# 8                     Silla Happy SI-0377 Andreu World
# 9             Silla New Anna SI-1370/1372 Andreu World
# 10                   Silla Carlotta Small Andreu World
# 11                     Silla Carlotta Big Andreu World
# 12                             Silla Solo Andreu World
# 13                   Sillón Solo tapizado Andreu World
# 14                     Sillón Solo madera Andreu World
# 15                           Silla Serena Andreu World
# ...

# %% [markdown]
# ### Deletion of unwanted columns

# %%
df_combined_andreu_sillas_sillones.drop(['Title'], axis=1, inplace=True)

# %%
df_combined_andreu_sillas_sillones.head()
# Out:
#                                          Description     Price Category  \
# 0  Silla con respaldo de roble en base de 4 patas...  474,32 €    Silla
# 1  Silla apilable tapizada con base estilo patín ...  491,26 €    Silla
# 2  Silla tapizada en tela o piel con base estilo ...  562,65 €    Silla
# 3  Silla tapizada en base de 4 patas en madera ma...  572,33 €    Silla
# 4  Silla en acabado de madera maciza de haya. Dim...  740,52 €    Silla
#
#                            Product       Company
# 0          Lineal SI-0760/SO-0761   Andreu World
# 1  Lineal comfort SI-0594/SO-0595   Andreu World
# 2  Lineal comfort SI-0567/SO-0568   Andreu World
# 3  Lineal comfort SI-0606/SO-0607   Andreu World
# 4                     Nub SI-1449   Andreu World

# %% [markdown]
# # Exporting IPYNB 'Jupyter' format to XLSX 'Excel'

# %%
with pd.ExcelWriter('Andreu-Sillas-Sillones.xlsx') as writer:
    df_combined_andreu_sillas_sillones.to_excel(writer, sheet_name='Andreu-Sillas-Sillones')
