# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd

# %%
url_lluesma = "https://www.muebleslluesma.com/2189-butacas-viccarbe"
page_lluesma = urlopen(url_lluesma)

soup_lluesma = bs(page_lluesma, 'html.parser')
print(soup_lluesma.prettify().splitlines()[0:30])





names_lluesma = soup_lluesma.find_all('h3', class_='h3 product-title')

for name in names_lluesma[0:20]:
    print(name.prettify())
    
description_lluesma = soup_lluesma.find_all('div', class_='product-description-short')

for description in description_lluesma[0:20]:
    print(description.prettify())

regular_prices_lluesma = soup_lluesma.find_all('span', class_='regular-price')

for regular_prices in regular_prices_lluesma[0:20]:
    print(regular_prices.prettify())
# Out:
# ['<!DOCTYPE html>', '<html class="default" lang="es-ES">', ' <head>', '  <meta charset="utf-8"/>', '  <meta content="ie=edge" http-equiv="x-ua-compatible"/>', '  <title>', '   Butacas de Viccarbe. Muebles Lluesma', '  </title>', '  <meta content="Butacas de Viccaber son sinónimo de vanguardia y actualidad. Butacas suaves y confortables. Visita nuestra tienda online." name="description"/>', '  <meta content="" name="keywords"/>', '  <link href="https://www.muebleslluesma.com/2189-butacas-viccarbe" rel="canonical"/>', '  <script type="application/ld+json">', '   {', '    "@context": "https://schema.org",', '    "@type": "Organization",', '    "name" : "Muebles Lluesma",', '    "url" : "https://www.muebleslluesma.com/",', '        "logo": {', '      "@type": "ImageObject",', '        "url":"https://www.muebleslluesma.com/img/logo-1647335525.jpg"', '    }', '      }', '  </script>', '  <script type="application/ld+json">', '   {', '    "@context": "https://schema.org",', '    "@type": "WebPage",', '    "isPartOf": {', '      "@type": "WebSite",', '      "url":  "https://www.muebleslluesma.com/",']
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/butacas-salon/16145-butaca-aleta-base-madera-viccarbe.html">
#   Butaca Aleta Lounge base madera Viccarbe
#  </a>
# </h3>
#
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/butacas-salon/16144-butaca-aleta-base-metal-viccarbe.html">
#   Butaca Aleta Lounge base metálica Viccarbe
#  </a>
# </h3>
#
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/butacas-salon/12233-butaca-ace-soft-con-base-madera-viccarbe.html">
#   Butaca Ace base madera Viccarbe
#  </a>
# </h3>
#
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/butacas-salon/1408-butaca-ace-soft-con-base-metalica-viccarbe.html">
#   Butaca Ace base metálica Viccarbe
#  </a>
# </h3>
#
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/butacas-salon/1414-butaca-nagi-viccarbe.html">
#   Butaca Nagi Viccarbe
#  </a>
# </h3>
#
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/butacas-salon/1410-butaca-colubi-viccarbe.html">
#   Butaca Colubi Viccarbe
#  </a>
# </h3>
#
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/butacas-salon/1409-butaca-brix-viccarbe.html">
#   Butaca Brix Viccarbe
#  </a>
# </h3>
#
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/butacas-salon/1400-butaca-levitt-viccarbe.html">
#   Butaca Levitt Viccarbe
#  </a>
# </h3>
#
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/sillas-de-comedor/21822-butaca-maarten-giratoria-metal-viccarbe.html">
#   Butaca Maarten Lounge base giratoria Viccarbe
#  </a>
# </h3>
#
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/sillas-de-comedor/21823-butaca-maarten-giratoria-madera-viccarbe.html">
#   Butaca Maarten Lounge giratoria madera Viccarbe
#  </a>
# </h3>
#
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/butacas-salon/1403-butaca-wrapp-viccarbe.html">
#   Butaca Wrapp base giratoria Viccarbe
#  </a>
# </h3>
#
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/butacas-salon/16831-butaca-wrapp-madera-viccarbe.html">
#   Butaca Wrapp base madera Viccarbe
#  </a>
# </h3>
#
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/butacas-salon/21801-butaca-funda-viccarbe.html">
#   Butaca Funda Lounge base cuatro patas Viccarbe
#  </a>
# </h3>
#
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/butacas-salon/26708-butaca-zoco-viccarbe.html">
#   Butaca Zoco Viccarbe
#  </a>
# </h3>
#
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/butacas-salon/26709-butaca-funda-bold-viccarbe.html">
#   Butaca Funda Bold Viccarbe
#  </a>
# </h3>
#
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/sofas-y-butacas-exterior/26743-butaca-zoco-outdoor-viccarbe.html">
#   Butaca Zoco Outdoor Viccarbe
#  </a>
# </h3>
#
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/butacas-salon/21803-butaca-copa-viccarbe.html">
#   Butaca Copa Lounge base cuatro patas madera Viccarbe
#  </a>
# </h3>
#
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/butacas-salon/1404-butaca-penta-viccarbe.html">
#   Butaca Penta Viccarbe
#  </a>
# </h3>
#
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/sillones/1405-butaca-fedele-viccarbe.html">
#   Sillón Fedele Viccarbe
#  </a>
# </h3>
#
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/puffs-para-salon/7122-pouf-fedele-viccarbe.html">
#   Pouf Fedele Viccarbe
#  </a>
# </h3>
#
# <div class="product-description-short" itemprop="description">
#  Butaca tapizada envolvente con o sin brazos en estructura de roble.
# </div>
#
# <div class="product-description-short" itemprop="description">
#  Butaca tapizada envolvente con o sin brazos en estructura de acero.
# </div>
#
# <div class="product-description-short" itemprop="description">
#  Butaca tapizada con o sin brazos de diseño inclinado en madera.
# </div>
#
# <div class="product-description-short" itemprop="description">
#  Butaca tapizada fija de diseño inclinado en estructura de acero.
# </div>
#
# <div class="product-description-short" itemprop="description">
#  Butaca tapizada con respaldo alto o bajo en base de acero fija o mecedora.
# </div>
#
# <div class="product-description-short" itemprop="description">
#  Butaca tapizada con brazos sobre bastidor con patas de acero lacado.
# </div>
#
# <div class="product-description-short" itemprop="description">
#  Butaca tapizada cuadrada con interior de madera sobre patas de acero.
# </div>
#
# <div class="product-description-short" itemprop="description">
#  Butaca con un brazo en madera maciza completamente tapizada en tela o cuero.
# </div>
#
# <div class="product-description-short" itemprop="description">
#  Butaca tapizada giratoria con o sin brazos en estructura de acero.
# </div>
#
# <div class="product-description-short" itemprop="description">
#  Butaca tapizada giratoria con o sin brazos en estructura de roble.
# </div>
#
# <div class="product-description-short" itemprop="description">
#  Butaca tapizada con diseño de orejas sobre base giratoria de acero.
# </div>
#
# <div class="product-description-short" itemprop="description">
#  Butaca tapizada con diseño de orejas sobre patas de madera de roble.
# </div>
#
# <div class="product-description-short" itemprop="description">
#  Butaca con respaldo y asiento tapizados y estructura metálica.
# </div>
#
# <div class="product-description-short" itemprop="description">
#  Butaca tapizada con estructura metálica, opción ruedas. Dimensiones: 84,5x66,1x74h cm.
# </div>
#
# <div class="product-description-short" itemprop="description">
#  Butaca tapizada con base cuatro patas de acero. Dimensiones: 95x96x93h cm.
# </div>
#
# <div class="product-description-short" itemprop="description">
#  Butaca Outdoor tapizada con estructura metálica. Dimensiones: 84,5x66,1x74h cm.
# </div>
#
# <div class="product-description-short" itemprop="description">
#  Butaca tapizada envolvente con estructura de madera de roble.
# </div>
#
# <div class="product-description-short" itemprop="description">
#  Butaca tapizada revestida de poliuretano fija o con base giratoria.
# </div>
#
# <div class="product-description-short" itemprop="description">
#  Sillón con diseño cerrado de madera completamente tapizada.
# </div>
#
# <div class="product-description-short" itemprop="description">
#  Pouf con diseño cerrado en madera maciza tapizado y revestida de poliuretano.
# </div>
#
# <span class="regular-price">
#  1.593,57 €
# </span>
#
# <span class="regular-price">
#  1.237,83 €
# </span>
#
# <span class="regular-price">
#  2.075,15 €
# </span>
#
# <span class="regular-price">
#  1.362,46 €
# </span>
#
# <span class="regular-price">
#  1.497,98 €
# </span>
#
# <span class="regular-price">
#  1.104,73 €
# </span>
#
# <span class="regular-price">
#  1.281,39 €
# </span>
#
# <span class="regular-price">
#  1.593,57 €
# </span>
#
# <span class="regular-price">
#  793,76 €
# </span>
#
# <span class="regular-price">
#  1.132,56 €
# </span>
#
# <span class="regular-price">
#  1.452,00 €
# </span>
#
# <span class="regular-price">
#  1.334,63 €
# </span>
#
# <span class="regular-price">
#  964,37 €
# </span>
#
# <span class="regular-price">
#  701,80 €
# </span>
#
# <span class="regular-price">
#  2.008,60 €
# </span>
#
# <span class="regular-price">
#  968,00 €
# </span>
#
# <span class="regular-price">
#  799,81 €
# </span>
#
# <span class="regular-price">
#  1.059,96 €
# </span>
#
# <span class="regular-price">
#  1.059,96 €
# </span>
#
# <span class="regular-price">
#  600,16 €
# </span>

# %%
titles = []
descriptions = []
prices = []

for i in range(len(names_lluesma)):
    title = names_lluesma[i].text if names_lluesma[i] else None
    description = description_lluesma[i].text.strip() if description_lluesma[i] else None
    price = regular_prices_lluesma[i].text.replace('\n', '') if regular_prices_lluesma[i] else None
    
    titles.append(title)
    descriptions.append(description)
    prices.append(price)

df_lluesma = pd.DataFrame({'Title': titles, 'Description': descriptions, 'Price': prices})

df_lluesma.head(30)
# Out:
#                                                 Title  \
# 0            Butaca Aleta Lounge base madera Viccarbe
# 1          Butaca Aleta Lounge base metálica Viccarbe
# 2                     Butaca Ace base madera Viccarbe
# 3                   Butaca Ace base metálica Viccarbe
# 4                                Butaca Nagi Viccarbe
# 5                              Butaca Colubi Viccarbe
# 6                                Butaca Brix Viccarbe
# 7                              Butaca Levitt Viccarbe
# 8       Butaca Maarten Lounge base giratoria Viccarbe
# 9     Butaca Maarten Lounge giratoria madera Viccarbe
# 10               Butaca Wrapp base giratoria Viccarbe
# 11                  Butaca Wrapp base madera Viccarbe
# 12     Butaca Funda Lounge base cuatro patas Viccarbe
# 13                               Butaca Zoco Viccarbe
# 14                         Butaca Funda Bold Viccarbe
# 15                       Butaca Zoco Outdoor Viccarbe
# 16  Butaca Copa Lounge base cuatro patas madera Vi...
# 17                              Butaca Penta Viccarbe
# 18                             Sillón Fedele Viccarbe
# 19                               Pouf Fedele Viccarbe
#
#                                           Description       Price
# 0   Butaca tapizada envolvente con o sin brazos en...  1.593,57 €
# 1   Butaca tapizada envolvente con o sin brazos en...  1.237,83 €
# 2   Butaca tapizada con o sin brazos de diseño inc...  2.075,15 €
# 3   Butaca tapizada fija de diseño inclinado en es...  1.362,46 €
# 4   Butaca tapizada con respaldo alto o bajo en ba...  1.497,98 €
# 5   Butaca tapizada con brazos sobre bastidor con ...  1.104,73 €
# 6   Butaca tapizada cuadrada con interior de mader...  1.281,39 €
# 7   Butaca con un brazo en madera maciza completam...  1.593,57 €
# 8   Butaca tapizada giratoria con o sin brazos en ...    793,76 €
# 9   Butaca tapizada giratoria con o sin brazos en ...  1.132,56 €
# 10  Butaca tapizada con diseño de orejas sobre bas...  1.452,00 €
# 11  Butaca tapizada con diseño de orejas sobre pat...  1.334,63 €
# 12  Butaca con respaldo y asiento tapizados y estr...    964,37 €
# 13  Butaca tapizada con estructura metálica, opció...    701,80 €
# 14  Butaca tapizada con base cuatro patas de acero...  2.008,60 €
# 15  Butaca Outdoor tapizada con estructura metálic...    968,00 €
# 16  Butaca tapizada envolvente con estructura de m...    799,81 €
# 17  Butaca tapizada revestida de poliuretano fija ...  1.059,96 €
# 18  Sillón con diseño cerrado de madera completame...  1.059,96 €
# 19  Pouf con diseño cerrado en madera maciza tapiz...    600,16 €

# %%
pd.set_option('display.max_rows', None)

df_combined_viccarbe_butacas = df_lluesma
df_combined_viccarbe_butacas.head(200)
# Out:
#                                                 Title  \
# 0            Butaca Aleta Lounge base madera Viccarbe
# 1          Butaca Aleta Lounge base metálica Viccarbe
# 2                     Butaca Ace base madera Viccarbe
# 3                   Butaca Ace base metálica Viccarbe
# 4                                Butaca Nagi Viccarbe
# 5                              Butaca Colubi Viccarbe
# 6                                Butaca Brix Viccarbe
# 7                              Butaca Levitt Viccarbe
# 8       Butaca Maarten Lounge base giratoria Viccarbe
# 9     Butaca Maarten Lounge giratoria madera Viccarbe
# 10               Butaca Wrapp base giratoria Viccarbe
# 11                  Butaca Wrapp base madera Viccarbe
# 12     Butaca Funda Lounge base cuatro patas Viccarbe
# 13                               Butaca Zoco Viccarbe
# 14                         Butaca Funda Bold Viccarbe
# 15                       Butaca Zoco Outdoor Viccarbe
# 16  Butaca Copa Lounge base cuatro patas madera Vi...
# 17                              Butaca Penta Viccarbe
# 18                             Sillón Fedele Viccarbe
# 19                               Pouf Fedele Viccarbe
#
#                                           Description       Price
# 0   Butaca tapizada envolvente con o sin brazos en...  1.593,57 €
# 1   Butaca tapizada envolvente con o sin brazos en...  1.237,83 €
# 2   Butaca tapizada con o sin brazos de diseño inc...  2.075,15 €
# 3   Butaca tapizada fija de diseño inclinado en es...  1.362,46 €
# 4   Butaca tapizada con respaldo alto o bajo en ba...  1.497,98 €
# 5   Butaca tapizada con brazos sobre bastidor con ...  1.104,73 €
# 6   Butaca tapizada cuadrada con interior de mader...  1.281,39 €
# 7   Butaca con un brazo en madera maciza completam...  1.593,57 €
# 8   Butaca tapizada giratoria con o sin brazos en ...    793,76 €
# 9   Butaca tapizada giratoria con o sin brazos en ...  1.132,56 €
# 10  Butaca tapizada con diseño de orejas sobre bas...  1.452,00 €
# 11  Butaca tapizada con diseño de orejas sobre pat...  1.334,63 €
# 12  Butaca con respaldo y asiento tapizados y estr...    964,37 €
# 13  Butaca tapizada con estructura metálica, opció...    701,80 €
# 14  Butaca tapizada con base cuatro patas de acero...  2.008,60 €
# 15  Butaca Outdoor tapizada con estructura metálic...    968,00 €
# 16  Butaca tapizada envolvente con estructura de m...    799,81 €
# 17  Butaca tapizada revestida de poliuretano fija ...  1.059,96 €
# 18  Sillón con diseño cerrado de madera completame...  1.059,96 €
# 19  Pouf con diseño cerrado en madera maciza tapiz...    600,16 €

# %%
with pd.ExcelWriter('Viccarbe-Butacas.xlsx') as writer:
    df_combined_viccarbe_butacas.to_excel(writer, sheet_name='Viccarbe-Butacas')
