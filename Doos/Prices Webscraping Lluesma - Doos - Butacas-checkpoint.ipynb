# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd

# %%
url_lluesma = "https://www.muebleslluesma.com/2557-butacas-doos"
page_lluesma = urlopen(url_lluesma)

soup_lluesma = bs(page_lluesma, 'html.parser')
print(soup_lluesma.prettify().splitlines()[0:30])

names_lluesma = soup_lluesma.find_all('h3', class_='h3 product-title')

for name in names_lluesma[0:20]:
    print(name.prettify())

description_lluesma = soup_lluesma.find_all('div', class_='product-description-short')

for description in description_lluesma[0:20]:
    print(description.prettify())

regular_prices_lluesma = soup_lluesma.find_all('span', class_='regular-price')

for regular_prices in regular_prices_lluesma[0:20]:
    print(regular_prices.prettify())
# Out:
# ['<!DOCTYPE html>', '<html class="default" lang="es-ES">', ' <head>', '  <meta charset="utf-8"/>', '  <meta content="ie=edge" http-equiv="x-ua-compatible"/>', '  <title>', '   Butacas y sillones contemporáneos y ergonómicos de Doos design. Catálogo completo de sillones y butacas para salón de Doos.', '  </title>', '  <meta content="Compra butacas de diseño moderno y gran comodidad Doos design. Distribuidor oficial de DOOS design" name="description"/>', '  <meta content="" name="keywords"/>', '  <link href="https://www.muebleslluesma.com/2557-butacas-doos" rel="canonical"/>', '  <script type="application/ld+json">', '   {', '    "@context": "https://schema.org",', '    "@type": "Organization",', '    "name" : "Muebles Lluesma",', '    "url" : "https://www.muebleslluesma.com/",', '        "logo": {', '      "@type": "ImageObject",', '        "url":"https://www.muebleslluesma.com/img/logo-1647335525.jpg"', '    }', '      }', '  </script>', '  <script type="application/ld+json">', '   {', '    "@context": "https://schema.org",', '    "@type": "WebPage",', '    "isPartOf": {', '      "@type": "WebSite",', '      "url":  "https://www.muebleslluesma.com/",']
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/sillones/25427-sillon-lounge-blur-madera-doos.html">
#   Sillón lounge Blur madera Doos
#  </a>
# </h3>
#
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/butacas-salon/25464-butaca-amable-doos.html">
#   Butaca Amable Doos
#  </a>
# </h3>
#
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/sillones/22551-sillon-aurora-doos.html">
#   Sillón Aurora Doos
#  </a>
# </h3>
#
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/sillones/22552-sillon-boxy-doos.html">
#   Sillón Boxy Doos
#  </a>
# </h3>
#
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/butacas-salon/22555-sillon-cleo-madera-doos.html">
#   Butaca Cleo madera Doos
#  </a>
# </h3>
#
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/butacas-salon/22570-sillon-cleo-cromado-doos.html">
#   Butaca Cleo metal Doos
#  </a>
# </h3>
#
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/sillones/22558-sillon-king-b02-giratorio-doos.html">
#   Sillón giratorio King Doos
#  </a>
# </h3>
#
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/butacas-salon/22557-sillon-mecedor-king-b01-doos.html">
#   Butaca mecedora King Doos
#  </a>
# </h3>
#
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/butacas-salon/22566-sillon-paris-b01-doos.html">
#   Butaca Paris Doos
#  </a>
# </h3>
#
# <h3 class="h3 product-title" itemprop="name">
#  <a href="https://www.muebleslluesma.com/sillones/25428-sillon-lounge-blur-metal-doos.html">
#   Sillón lounge Blur metal Doos
#  </a>
# </h3>
#
# <div class="product-description-short" itemprop="description">
#  Sillón lounge tapizado con patas de madera de haya. Dimensiones: 57x60x72h cm.
# </div>
#
# <div class="product-description-short" itemprop="description">
#  Butaca tapizada con estructura y patas de madera de haya. Dimensiones: 70x86x125h cm.
# </div>
#
# <div class="product-description-short" itemprop="description">
#  Sillón tapizado con estructura de madera de pino y patas de madera o metal.
# </div>
#
# <div class="product-description-short" itemprop="description">
#  Sillón tapizado con base de ruedas giratorias o patas de madera.
# </div>
#
# <div class="product-description-short" itemprop="description">
#  Butaca tapizada con base cónica o zócalo de madera de haya. Dimensiones: 87x64x76h cm.
# </div>
#
# <div class="product-description-short" itemprop="description">
#  Butaca tapizada con patas de metal cromado o negro liso. Dimensiones: 87x64x76h cm.
# </div>
#
# <div class="product-description-short" itemprop="description">
#  Sillón tapizado con base de metal giratoria con ligero balancín. Dimensiones: 72x80x102h cm.
# </div>
#
# <div class="product-description-short" itemprop="description">
#  Butaca con base de metal y ligero movimiento balancín. Dimensiones: 72x80x102h cm.
# </div>
#
# <div class="product-description-short" itemprop="description">
#  Butaca tapizada con patas de madera de haya. Dimensiones: 66x82x89h cm.
# </div>
#
# <div class="product-description-short" itemprop="description">
#  Sillón lounge tapizado con base de metal en epoxi liso o texturizado. Dimensiones: 57x60x72h cm.
# </div>
#
# <span class="regular-price">
#  592,90 €
# </span>
#
# <span class="regular-price">
#  1.621,40 €
# </span>
#
# <span class="regular-price">
#  943,80 €
# </span>
#
# <span class="regular-price">
#  815,54 €
# </span>
#
# <span class="regular-price">
#  895,40 €
# </span>
#
# <span class="regular-price">
#  1.040,60 €
# </span>
#
# <span class="regular-price">
#  1.379,40 €
# </span>
#
# <span class="regular-price">
#  1.229,36 €
# </span>
#
# <span class="regular-price">
#  863,94 €
# </span>
#
# <span class="regular-price">
#  513,04 €
# </span>

# %%
titles = []
descriptions = []
prices = []

for i in range(len(names_lluesma)):
    title = names_lluesma[i].text if names_lluesma[i] else None
    description = description_lluesma[i].text.strip() if description_lluesma[i] else None
    price = regular_prices_lluesma[i].text if regular_prices_lluesma[i] else None
    
    titles.append(title)
    descriptions.append(description)
    prices.append(price)

df_lluesma = pd.DataFrame({'Title': titles, 'Description': descriptions, 'Price': prices})

df_lluesma.head(30)
# Out:
#                             Title  \
# 0  Sillón lounge Blur madera Doos
# 1              Butaca Amable Doos
# 2              Sillón Aurora Doos
# 3                Sillón Boxy Doos
# 4         Butaca Cleo madera Doos
# 5          Butaca Cleo metal Doos
# 6      Sillón giratorio King Doos
# 7       Butaca mecedora King Doos
# 8               Butaca Paris Doos
# 9   Sillón lounge Blur metal Doos
#
#                                          Description       Price
# 0  Sillón lounge tapizado con patas de madera de ...    592,90 €
# 1  Butaca tapizada con estructura y patas de made...  1.621,40 €
# 2  Sillón tapizado con estructura de madera de pi...    943,80 €
# 3  Sillón tapizado con base de ruedas giratorias ...    815,54 €
# 4  Butaca tapizada con base cónica o zócalo de ma...    895,40 €
# 5  Butaca tapizada con patas de metal cromado o n...  1.040,60 €
# 6  Sillón tapizado con base de metal giratoria co...  1.379,40 €
# 7  Butaca con base de metal y ligero movimiento b...  1.229,36 €
# 8  Butaca tapizada con patas de madera de haya. D...    863,94 €
# 9  Sillón lounge tapizado con base de metal en ep...    513,04 €

# %%
df_combined_doos_butacas = df_lluesma
df_combined_doos_butacas.head(30)
# Out:
#                             Title  \
# 0  Sillón lounge Blur madera Doos
# 1              Butaca Amable Doos
# 2              Sillón Aurora Doos
# 3                Sillón Boxy Doos
# 4         Butaca Cleo madera Doos
# 5          Butaca Cleo metal Doos
# 6      Sillón giratorio King Doos
# 7       Butaca mecedora King Doos
# 8               Butaca Paris Doos
# 9   Sillón lounge Blur metal Doos
#
#                                          Description       Price
# 0  Sillón lounge tapizado con patas de madera de ...    592,90 €
# 1  Butaca tapizada con estructura y patas de made...  1.621,40 €
# 2  Sillón tapizado con estructura de madera de pi...    943,80 €
# 3  Sillón tapizado con base de ruedas giratorias ...    815,54 €
# 4  Butaca tapizada con base cónica o zócalo de ma...    895,40 €
# 5  Butaca tapizada con patas de metal cromado o n...  1.040,60 €
# 6  Sillón tapizado con base de metal giratoria co...  1.379,40 €
# 7  Butaca con base de metal y ligero movimiento b...  1.229,36 €
# 8  Butaca tapizada con patas de madera de haya. D...    863,94 €
# 9  Sillón lounge tapizado con base de metal en ep...    513,04 €

# %%
with pd.ExcelWriter('Doos-Butacas.xlsx') as writer:
    df_combined_doos_butacas.to_excel(writer, sheet_name='Doos-Butacas')
